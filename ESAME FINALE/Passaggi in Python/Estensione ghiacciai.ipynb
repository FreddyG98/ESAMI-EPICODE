# %%
import pandas as pd

# %%
Antartico = pd.read_csv(r'C:\Users\alfim\Desktop\EPICODE\Esami e Build Week\Esami\ESAME FINALE\Ghiacciai\Estensione ghiacciao ANTARTICO.csv')
Antartico
# Out:
#         Entity Code  Year  Maximum Antarctic sea ice extent  \
# 0   Antarctica  ATA  1979                            18.196
# 1   Antarctica  ATA  1980                            18.817
# 2   Antarctica  ATA  1981                            18.597
# 3   Antarctica  ATA  1982                            18.353
# 4   Antarctica  ATA  1983                            18.585
# 5   Antarctica  ATA  1984                            18.171
# 6   Antarctica  ATA  1985                            18.703
# 7   Antarctica  ATA  1986                            17.683
# 8   Antarctica  ATA  1987                            18.246
# 9   Antarctica  ATA  1988                            18.307
# 10  Antarctica  ATA  1989                            18.121
# 11  Antarctica  ATA  1990                            18.193
# 12  Antarctica  ATA  1991                            18.313
# 13  Antarctica  ATA  1992                            18.147
# 14  Antarctica  ATA  1993                            18.543
# ...

# %%
Antartico = Antartico.rename(columns = {'Maximum Antarctic sea ice extent':'Maximum sea ice extent' , 'Minimum Antarctic sea ice extent':'Minimum sea ice extent'})
Antartico
# Out:
#         Entity Code  Year  Maximum sea ice extent  Minimum sea ice extent
# 0   Antarctica  ATA  1979                  18.196                   3.141
# 1   Antarctica  ATA  1980                  18.817                   2.818
# 2   Antarctica  ATA  1981                  18.597                   2.873
# 3   Antarctica  ATA  1982                  18.353                   3.129
# 4   Antarctica  ATA  1983                  18.585                   3.070
# 5   Antarctica  ATA  1984                  18.171                   2.677
# 6   Antarctica  ATA  1985                  18.703                   2.836
# 7   Antarctica  ATA  1986                  17.683                   3.193
# 8   Antarctica  ATA  1987                  18.246                   3.254
# 9   Antarctica  ATA  1988                  18.307                   2.886
# 10  Antarctica  ATA  1989                  18.121                   2.978
# 11  Antarctica  ATA  1990                  18.193                   3.036
# ...

# %%
Artico = pd.read_csv(r'C:\Users\alfim\Desktop\EPICODE\Esami e Build Week\Esami\ESAME FINALE\Ghiacciai\Estensione ghiacciao ARTICO.csv')
Artico
# Out:
#           Entity  Code  Year  Minimum Arctic sea ice extent  \
# 0   Arctic Ocean   NaN  1979                          7.051
# 1   Arctic Ocean   NaN  1980                          7.667
# 2   Arctic Ocean   NaN  1981                          7.138
# 3   Arctic Ocean   NaN  1982                          7.302
# 4   Arctic Ocean   NaN  1983                          7.395
# 5   Arctic Ocean   NaN  1984                          6.805
# 6   Arctic Ocean   NaN  1985                          6.698
# 7   Arctic Ocean   NaN  1986                          7.411
# 8   Arctic Ocean   NaN  1987                          7.279
# 9   Arctic Ocean   NaN  1988                          7.369
# 10  Arctic Ocean   NaN  1989                          7.008
# 11  Arctic Ocean   NaN  1990                          6.143
# 12  Arctic Ocean   NaN  1991                          6.473
# 13  Arctic Ocean   NaN  1992                          7.474
# 14  Arctic Ocean   NaN  1993                          6.397
# ...

# %%
Artico = Artico.rename(columns = {'Minimum Arctic sea ice extent':'Minimum sea ice extent' , 'Maximum Arctic sea ice extent':'Maximum sea ice extent'})
Artico
# Out:
#           Entity  Code  Year  Minimum sea ice extent  Maximum sea ice extent
# 0   Arctic Ocean   NaN  1979                   7.051                  16.175
# 1   Arctic Ocean   NaN  1980                   7.667                  15.955
# 2   Arctic Ocean   NaN  1981                   7.138                  15.604
# 3   Arctic Ocean   NaN  1982                   7.302                  15.974
# 4   Arctic Ocean   NaN  1983                   7.395                  16.006
# 5   Arctic Ocean   NaN  1984                   6.805                  15.299
# 6   Arctic Ocean   NaN  1985                   6.698                  15.466
# 7   Arctic Ocean   NaN  1986                   7.411                  15.785
# 8   Arctic Ocean   NaN  1987                   7.279                  16.050
# 9   Arctic Ocean   NaN  1988                   7.369                  15.583
# 10  Arctic Ocean   NaN  1989                   7.008                  15.495
# ...

# %%
Artico = Artico[['Entity','Code','Year','Maximum sea ice extent','Minimum sea ice extent']]

# %%
Estensione_ghiacciai = pd.concat([Antartico,Artico])
Estensione_ghiacciai
# Out:
#           Entity Code  Year  Maximum sea ice extent  Minimum sea ice extent
# 0     Antarctica  ATA  1979                  18.196                   3.141
# 1     Antarctica  ATA  1980                  18.817                   2.818
# 2     Antarctica  ATA  1981                  18.597                   2.873
# 3     Antarctica  ATA  1982                  18.353                   3.129
# 4     Antarctica  ATA  1983                  18.585                   3.070
# ..           ...  ...   ...                     ...                     ...
# 42  Arctic Ocean  NaN  2021                  14.390                   4.952
# 43  Arctic Ocean  NaN  2022                  14.612                   4.897
# 44  Arctic Ocean  NaN  2023                  14.176                   4.371
# 45  Arctic Ocean  NaN  2024                  14.607                   4.379
# 46  Arctic Ocean  NaN  2025                  13.745                     NaN
#
# [94 rows x 5 columns]

# %%
Estensione_ghiacciai.to_csv('Estensione ghiacciai.csv' , index = None)

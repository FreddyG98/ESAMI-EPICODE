# %%
import pandas as pd

# %%
Country_list = pd.read_csv(r'C:\Users\alfim\Desktop\EPICODE\Esami e Build Week\Esami\ESAME FINALE\Emissioni CO2\Emissione CO2 pro capite.csv')
Country_list
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1750      AFG   2802560.0           NaN       0.000
# 1      Afghanistan  1751      AFG         NaN           NaN       0.000
# 2      Afghanistan  1752      AFG         NaN           NaN       0.000
# 3      Afghanistan  1753      AFG         NaN           NaN       0.000
# 4      Afghanistan  1754      AFG         NaN           NaN       0.000
# ...            ...   ...      ...         ...           ...         ...
# 50186     Zimbabwe  2019      ZWE  15271377.0  2.514642e+10       0.473
# 50187     Zimbabwe  2020      ZWE  15526888.0  2.317871e+10       0.496
# 50188     Zimbabwe  2021      ZWE  15797220.0  2.514009e+10       0.531
# 50189     Zimbabwe  2022      ZWE  16069061.0  2.590159e+10       0.531
# 50190     Zimbabwe  2023      ZWE  16340829.0           NaN       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
Country_list = Country_list.drop_duplicates(subset = ['country'])
Country_list
# Out:
#                  country  year iso_code   population  gdp  cement_co2  \
# 0            Afghanistan  1750      AFG    2802560.0  NaN         0.0
# 274               Africa  1750      NaN   80349715.0  NaN         0.0
# 548         Africa (GCP)  1850      NaN          NaN  NaN         NaN
# 722              Albania  1850      ALB     501490.0  NaN         NaN
# 896              Algeria  1850      DZA    2852648.0  NaN         NaN
# ...                  ...   ...      ...          ...  ...         ...
# 49122  Wallis and Futuna  1851      WLF          NaN  NaN         NaN
# 49295              World  1750      NaN  753279296.0  NaN         NaN
# 49569              Yemen  1850      YEM    2738504.0  NaN         NaN
# 49743             Zambia  1850      ZMB    1579865.0  NaN         NaN
# 49917           Zimbabwe  1750      ZWE     438745.0  NaN         0.0
#
#        cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
Country_list = Country_list.country

# %%
Country_list.to_csv('Country_list.csv' , index = None)

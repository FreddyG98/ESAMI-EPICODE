# %%
import pandas as pd

# %%
Lista_emissioni = pd.read_csv(r'C:\Users\alfim\Desktop\EPICODE\Esami e Build Week\Esami\ESAME FINALE\Emissioni CO2\Emissione CO2 per fonte.csv')
Lista_emissioni
# Out:
#             Entity Code  Year  Annual CO₂ emissions from other industry  \
# 0      Afghanistan  AFG  1970                                       NaN
# 1      Afghanistan  AFG  1971                                       NaN
# 2      Afghanistan  AFG  1972                                       NaN
# 3      Afghanistan  AFG  1973                                       NaN
# 4      Afghanistan  AFG  1974                                       NaN
# ...            ...  ...   ...                                       ...
# 34757     Zimbabwe  ZWE  1989                                       NaN
# 34758     Zimbabwe  ZWE  1990                                       NaN
# 34759     Zimbabwe  ZWE  1991                                       NaN
# 34760     Zimbabwe  ZWE  1992                                       NaN
# 34761     Zimbabwe  ZWE  1993                                       NaN
#
#        Annual CO₂ emissions from flaring  Annual CO₂ emissions from cement  \
# ...

# %%
nomi_colonne = list(Lista_emissioni)
nomi_colonne = nomi_colonne[3:]
nomi_colonne
# Out:
# ['Annual CO₂ emissions from other industry',
#  'Annual CO₂ emissions from flaring',
#  'Annual CO₂ emissions from cement',
#  'Annual CO₂ emissions from gas',
#  'Annual CO₂ emissions from oil',
#  'Annual CO₂ emissions from coal']

# %%
df_emissioni = pd.DataFrame({'Tipi di emissioni':nomi_colonne})
df_emissioni
# Out:
#                           Tipi di emissioni
# 0  Annual CO₂ emissions from other industry
# 1         Annual CO₂ emissions from flaring
# 2          Annual CO₂ emissions from cement
# 3             Annual CO₂ emissions from gas
# 4             Annual CO₂ emissions from oil
# 5            Annual CO₂ emissions from coal

# %%
df_emissioni['Tipi di emissioni'] = df_emissioni['Tipi di emissioni'].str.split(pat = "from ").str[1]
df_emissioni
# Out:
#   Tipi di emissioni
# 0    other industry
# 1           flaring
# 2            cement
# 3               gas
# 4               oil
# 5              coal

# %%
df_emissioni.to_csv('Lista Emissioni.csv' , index = None)
